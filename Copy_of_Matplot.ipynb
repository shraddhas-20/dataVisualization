# %% [markdown]
# <a href="https://colab.research.google.com/github/shraddhas-20/dataVisualization/blob/main/Copy_of_Matplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data = {
    'date_string': ['2026-01-15', '2026-02-20', '2026-03-05', '2026-04-12'],
    'sales': [250, 300, 150, 400]
}
df = pd.DataFrame(data)
df['date_string'] = pd.to_datetime(df['date_string'])

plt.plot(df['date_string'], df['sales'])

# %%
df = pd.read_csv('Fish.csv')
df
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
x = df['Length1']
y = df['Weight']

plt.plot(x,y)
plt.title("Line Graph for length1 vs weight")
plt.xlabel('length1')
plt.ylabel("Weight")

plt.show()

# %%
m = df["Length2"]
n = df["Weight"]

plt.scatter(x,y)

# %%
no_of_species = df["Species"].value_counts()

print(no_of_species)
# Out:
# Species
# Perch        56
# Bream        35
# Roach        20
# Pike         17
# Smelt        14
# Parkki       11
# Whitefish     6
# Name: count, dtype: int64

# %%
plt.pie(no_of_species, labels = no_of_species.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x7ee92f173680>,
# ...
#  [Text(0.49259980877944665, 0.98353720234186, 'Perch'),
#   Text(-1.0692251705816584, 0.25837479481292963, 'Bream'),
#   Text(-0.7263011941968639, -0.8261274570598713, 'Roach'),
#   Text(0.010866859821049533, -1.0999463220346846, 'Pike'),
#   Text(0.6412776401130628, -0.8937354129109024, 'Smelt'),
#   Text(0.988355640625046, -0.4828593249018342, 'Parkki'),
#   Text(1.0922792138871054, -0.1301004185626142, 'Whitefish')])

# %%
plt.hist(df['Species'])
# Out:
# (array([35., 20.,  0.,  6.,  0., 11., 56.,  0., 17., 14.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <BarContainer object of 10 artists>)
